# %% [markdown]
# # Default notebook
#
# This default notebook is executed using a Lakeflow job as defined in resources/sample_job.job.yml.

# %%
from var_etl.pipeline.gold_var_by_ticker import compute_var_by_ticker

catalog = dbutils.widgets.get("catalog")
schema  = dbutils.widgets.get("schema")

silver_table = dbutils.widgets.get("silver_table")
gold_var_table = dbutils.widgets.get("gold_var_table")

as_of_date = dbutils.widgets.get("as_of_date").strip()
look_back = int(dbutils.widgets.get("look_back"))
alpha = float(dbutils.widgets.get("alpha"))


spark.sql(f"USE CATALOG `{catalog}`")
spark.sql(f"USE SCHEMA `{schema}`")

df = spark.table(silver_table)

compute_var_by_ticker(
    df=df,
    spark=spark,
    as_of_date=as_of_date,
    look_back=look_back,
    alpha=alpha,
    gold_var_table=gold_var_table
)
